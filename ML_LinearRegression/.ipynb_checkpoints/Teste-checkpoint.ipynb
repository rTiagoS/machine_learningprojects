# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# # Linear Regression Project
#
# Congratulations! You just got some contract work with an Ecommerce company based in New York City that sells clothing online but they also have in-store style and clothing advice sessions. Customers come in to the store, have sessions/meetings with a personal stylist, then they can go home and order either on a mobile app or website for the clothes they want.
#
# The company is trying to decide whether to focus their efforts on their mobile app experience or their website. They've hired you on contract to help them figure it out! Let's get started!
#
# Just follow the steps below to analyze the customer data (it's fake, don't worry I didn't give you real credit card numbers or emails).

# %% [markdown]
# ## Imports
# ** Import pandas, numpy, matplotlib,and seaborn. Then set %matplotlib inline
# (You'll import sklearn as you need it.)**

# %%
#A biblioteca Pandas oferece estruturas e operações para manipular tabelas numéricas e séries temporais.
import pandas as pd 
#A biblioteca Numpy fornece um grande conjunto de funções e operações de biblioteca que ajudam
#os programadores a executar facilmente cálculos numéricos.
import numpy as np

#A biblioteca matplotlib é principal para visualização de dados.
import matplotlib.pyplot as plt

#A biblioteca seaborn atua em conjunto com a biblioteca matplotlib para visualização de dados. Modifiquei
import seaborn as sns

# %%
#Visualização dos dados no próprio jupyter-notebook.
# %matplotlib inline

# %% [markdown]
# ## Get the Data
#
# We'll work with the Ecommerce Customers csv file from the company. It has Customer info, suchas Email, Address, and their color Avatar. Then it also has numerical value columns:
#
# * Avg. Session Length: Average session of in-store style advice sessions.
# * Time on App: Average time spent on App in minutes
# * Time on Website: Average time spent on Website in minutes
# * Length of Membership: How many years the customer has been a member.
#
# ** Read in the Ecommerce Customers csv file as a DataFrame called customers.**

# %%
#Ler os dados do dataset 'Ecommerce Customers.csv' como um DataFrame chamado customers.
customers = pd.read_csv('Ecommerce Customers')

# %%
#Visualizar o cabeçalho do dataset.
customers.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
#Visualizar informações complementares do dataset.
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
#Visualizar algumas operações estatísticas com o dataset.
customers.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
#Analisar colunas que existem no dataset.
customers.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %% [markdown]
# **Check the head of customers, and check out its info() and describe() methods.**

# %% [markdown]
# ## Exploratory Data Analysis
#
# **Let's explore the data!**
#
# For the rest of the exercise we'll only be using the numerical data of the csv file.
# ___
# **Use seaborn to create a jointplot to compare the Time on Website and Yearly Amount Spent columns. Does the correlation make sense?**

# %%
sns.set_palette("GnBu_d")
sns.set_style('whitegrid')

# %%
#Não é o plot que foi pedido, mas fica aqui como opção para um possível plot.
sns.pairplot(customers, x_vars = ["Time on Website"], y_vars=["Yearly Amount Spent"])

# %%
#Cria não apenas histogramas, mas também correlações entre os dados plotados.
#Observa-se
sns.jointplot(x="Time on Website", y="Yearly Amount Spent", data=customers)

# %% [markdown]
# ** Do the same but with the Time on App column instead. **

# %%
sns.jointplot(x="Time on App", y = "Yearly Amount Spent", data= customers)

# %%
sns.jointplot(x="Time on App", y = "Yearly Amount Spent", data= customers)

# %% [markdown]
# ** Use jointplot to create a 2D hex bin plot comparing Time on App and Length of Membership.**

# %%
sns.jointplot(x="Time on App", y="Length of Membership", kind="hex", data=customers)

# %% [markdown]
# **Let's explore these types of relationships across the entire data set. Use [pairplot](https://stanford.edu/~mwaskom/software/seaborn/tutorial/axis_grids.html#plotting-pairwise-relationships-with-pairgrid-and-pairplot) to recreate the plot below.(Don't worry about the the colors)**

# %%
sns.pairplot(customers)

# %% [markdown]
# **Based off this plot what looks to be the most correlated feature with Yearly Amount Spent?**

# %%
# A correlação entre duas ou mais variáveis aleatórias é uma relação estatística (causal ou não causal).
# Informalmemente, correlação é sinônimo de dependência. Além disso, os coeficientes de correlação são métodos
# estatísticos para se medir as relações entre variáveis e o que elas representam.

# Em síntese, o que a correlação procura entender é como uma variável se comporta em um cenário
# onde outra está variando, visando identificar se existe alguma relação entre a variabilidade de ambas.
# Embora não implique em causalidade, o coeficiente de correlação exprime em números essa relação, ou seja,
# quantifica a relação entre as variáveis.

# A característica mais correlacionada com "Yearly Amount Spent" parece ser a "Length of Membership", pois existe
# uma tendênciar linear entre Y e X.

# %% [markdown]
# **Create a linear model plot (using seaborn's lmplot) of  Yearly Amount Spent vs. Length of Membership. **

# %%
#Plota dados e ajusta uma curva de regressão linear para as variáveis do dataset inseridas.

(sns.lmplot(x = "Length of Membership", y = "Yearly Amount Spent", data=customers, aspect=1)).set(xlim=(-1,8),ylim=(0,900))

#Setar range do eixo X e Y na função lmplot:
#(sns.lmplot(x = "Length of Membership", y = "Yearly Amount Spent", data=customers, aspect=1)).set(xlim=(-1,8),ylim=(0,900))

# %% [markdown]
# ## Training and Testing Data
#
# Now that we've explored the data a bit, let's go ahead and split the data into training and testing sets.
# ** Set a variable X equal to the numerical features of the customers and a variable y equal to the "Yearly Amount Spent" column. **

# %%
#Variáveis do dataset que irão servir de parâmetros/inputs para gerar o modelo de regressão linear.
X = customers[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']]

# %%
#Variável target(alvo) que se espera prever o comportamento.
y = customers[['Yearly Amount Spent']]

# %% [markdown]
# ** Use model_selection.train_test_split from sklearn to split the data into training and testing sets. Set test_size=0.3 and random_state=101**

# %%
#Separar o dataset em uma parte para teste e outro para treino do modelo de regressão linear.

from sklearn.model_selection import train_test_split

# %%
# Função tupla que separa o dataset em treino e teste. É passado o tamanho do dataset de teste, a variável target (y)
# e as features do dataset (X).
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# ## Training the Model
#
# Now its time to train our model on our training data!
#
# ** Import LinearRegression from sklearn.linear_model **

# %%
#Importa o modelo de regressão linear da biblioteca sklearn.
from sklearn.linear_model import LinearRegression

# %% [markdown]
# **Create an instance of a LinearRegression() model named lm.**

# %%
#Criar instância do modelo de regressão linear com o nome de lm.
lm = LinearRegression()

# %% [markdown]
# ** Train/fit lm on the training data.**

# %%
#Treina o modelo de regressão linear com o dataset separado para treino(X_train,y_train).
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# **Print out the coefficients of the model**

# %%
#Fornece os coeficientes que indicam as correlações entre a variável target e as variáveis features do dataset.
#Cada um desses coeficientes relaciona a variável target "Yearly Amount Spent" com a coluna da feature respectiva.
lm.coef_
# Out:
# array([[25.98154972, 38.59015875,  0.19040528, 61.27909654]])

# %%
X_train.columns
# Out:
# Index(['Avg. Session Length', 'Time on App', 'Time on Website',
#        'Length of Membership'],
#       dtype='object')

# %% [markdown]
# ## Predicting Test Data
# Now that we have fit our model, let's evaluate its performance by predicting off the test values!
#
# ** Use lm.predict() to predict off the X_test set of the data.**

# %%
#Utiliza o dataset de teste para, posteriormente, comparar o que foi previsto com as features do dataset de teste
#comparando com os valores reais já previamente tabulados.
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([[456.44186104],
#        [402.72005312],
#        [409.2531539 ],
#        [591.4310343 ],
#        [590.01437275],
#        [548.82396607],
#        [577.59737969],
#        [715.44428115],
#        [473.7893446 ],
#        [545.9211364 ],
#        [337.8580314 ],
#        [500.38506697],
#        [552.93478041],
#        [409.6038964 ],
#        [765.52590754],
#        [545.83973731],
#        [693.25969124],
#        [507.32416226],
#        [573.10533175],
#        [573.2076631 ],
#        [397.44989709],
#        [555.0985107 ],
#        [458.19868141],
#        [482.66899911],
#        [559.2655959 ],
#        [413.00946082],
#        [532.25727408],
#        [377.65464817],
#        [535.0209653 ],
#        [447.80070905],
#        [595.54339577],
#        [667.14347072],
#        [511.96042791],
#        [573.30433971],
#        [505.02260887],
#        [565.30254655],
#        [460.38785393],
#        [449.74727868],
#        [422.87193429],
#        [456.55615271],
# ...

# %% [markdown]
# ** Create a scatterplot of the real test values versus the predicted values. **

# %%
#Plot que compara os valores previstos com os valores reais.
plt.scatter(y_test,predictions)
plt.xlabel('Y Teste (True Values)')
plt.ylabel('Predicted Values')
# Out:
# Text(0, 0.5, 'Predicted Values')

# %% [markdown]
# ## Evaluating the Model
#
# Let's evaluate our model performance by calculating the residual sum of squares and the explained variance score (R^2).
#
# ** Calculate the Mean Absolute Error, Mean Squared Error, and the Root Mean Squared Error. Refer to the lecture or to Wikipedia for the formulas**

# %%
#Importa funções de métricas de validação do modelo a partir da biblioteca sklearn.
from sklearn import metrics

# %%
print("MAE: ", metrics.mean_absolute_error(y_test,predictions))
print("MSE: ", metrics.mean_squared_error(y_test,predictions))
print("RMSE: ", np.sqrt(metrics.mean_squared_error(y_test,predictions)))
# Out:
# MAE:  7.228148653430838
# MSE:  79.81305165097461
# RMSE:  8.933815066978642

# %%
# A variância de uma variável aleatória ou processo estocástico é uma medida da sua dispersão estatística, 
# indicando "o quão longe" em geral os seus valores se encontram do valor esperado.
# Portanto, a função abaixo fornece a variância do modelo gerado. O valor fornecido revela "o quão correto" o modelo
# gerado é capaz de prever a variável target "Yearly Amount Spent".
metrics.explained_variance_score(y_test,predictions)
# Out:
# 0.9890771231889606

# %% [markdown]
# ## Residuals
#
# You should have gotten a very good model with a good fit. Let's quickly explore the residuals to make sure everything was okay with our data.
#
# **Plot a histogram of the residuals and make sure it looks normally distributed. Use either seaborn distplot, or just plt.hist().**

# %%
#Histograma dos resíduos. Se a distribuição for normal, é um bom sinal que a escolha do modelo foi boa.
sns.distplot(y_test-predictions, bins=50)

# %% [markdown]
# ## Conclusion
# We still want to figure out the answer to the original question, do we focus our efforst on mobile app or website development? Or maybe that doesn't even really matter, and Membership Time is what is really important.  Let's see if we can interpret the coefficients at all to get an idea.
#
# ** Recreate the dataframe below. **

# %%
#Gera uma tabela que relaciona cada coeficiente a respectiva feature.
coeffecients = pd.DataFrame([25.98154972, 38.59015875,  0.19040528, 61.27909654],['Avg. Session Length', 'Time on App', 'Time on Website',
       'Length of Membership'],columns=['Coeficientes'])
coeffecients
# Out:
#                       Coeficientes
# Avg. Session Length      25.981550
# Time on App              38.590159
# Time on Website           0.190405
# Length of Membership     61.279097

# %% [markdown]
# ** How can you interpret these coefficients? **

# %% [markdown]
# 1.Para cada aumento na unidade de Duração da Afiliação, a quantidade de dinheiro gasto por ano é incrementada
# de 61.28 doláres se todas as outras variáveis forem mantidas fixas.
#
# 2.A feature "Length of Membership" gera maior quantidade de doláres gasto por ano.
#
# 3.O tempo que o membro gasta no Website praticamente não gera incremento na renda anual.

# %% [markdown]
# **Do you think the company should focus more on their mobile app or on their website?**

# %% [markdown]
# 4.A companhia deve focar mais no Mobile App, pois o coeficiente de correlação entre o tempo gasto no App com o gasto anual, comparado com o Website, é muito superior. De acordo com o modelo, o Website não gera um retorno significante para a loja virtual. Além disso, a loja deve implementar formas de manter a fidelidade do cliente à loja virtual.

# %% [markdown]
# ## Great Job!
#
# Congrats on your contract work! The company loved the insights! Let's move on.
